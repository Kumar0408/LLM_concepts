# %%
import sys
from pathlib import Path

here = Path.cwd().resolve()
repo_root = here if (here / "src").exists() else here.parents[1]

if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %%
import torch
import os
import urllib

# %%
file_path = "the-verdict.txt"
with open(file_path, "r", encoding="utf-8") as file:
    text_data = file.read()

# %%
import tiktoken
tokenizer = tiktoken.get_encoding("gpt2")

# %%
total_characters = len(text_data)
total_tokens = len(tokenizer.encode(text_data))
print("Characters:", total_characters)
print("Tokens:", total_tokens)
# Out:
# Characters: 20479
# Tokens: 5145

# %%
train_ratio = 0.90
split_idx = int(train_ratio * len(text_data))
train_data = text_data[:split_idx]
val_data = text_data[split_idx:]

# %%
len(train_data), len(val_data)
# Out:
# (18431, 2048)

# %%
from src.gpt_blocks.data_loader import create_dataloader_v1

# %%
GPT_CONFIG_124M = {
    "vocab_size": 50257,
    "context_length": 256,
    "embed_dim": 768,
    "n_layers": 12,
    "n_heads": 12,
    "drop_rate": 0.1,
    "qkv_bias": False
}

# %%
torch.manual_seed(123)
train_loader = create_dataloader_v1(
        train_data,
        batch_size=2,
        max_length=GPT_CONFIG_124M["context_length"],
        stride=GPT_CONFIG_124M["context_length"],
        drop_last=True,
        shuffle=True,
        num_workers=0
)

val_loader = create_dataloader_v1(
        val_data,
        batch_size=2,
        max_length=GPT_CONFIG_124M["context_length"],
        stride=GPT_CONFIG_124M["context_length"],
        drop_last=False,
        shuffle=False,
        num_workers=0
)

# %%
print("Train loader:")
for x, y in train_loader:
    print(x.shape, y.shape)
# Out:
# Train loader:
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])

# %%
print("Val loader:")
for x, y in val_loader:
    print(x.shape, y.shape)
# Out:
# Val loader:
# torch.Size([2, 256]) torch.Size([2, 256])

# %%
from src.gpt_blocks.loss_calc import calc_loss_loader
from src.gpt_blocks.gpt_model import GPTModel

# %% [markdown]
# # Training

# %%
from src.gpt_blocks.train_llm import train_model

# %%
torch.manual_seed(123)
model = GPTModel(GPT_CONFIG_124M)
optimizer = torch.optim.AdamW(
model.parameters(),
lr=0.0004, weight_decay=0.1
)
num_epochs = 10
train_losses, val_losses, tokens_seen = train_model(
model, train_loader, val_loader, optimizer, device=torch.device("cpu"),
num_epochs=num_epochs, eval_freq=5, eval_iter=5,
start_context="Every effort moves you", tokenizer=tokenizer
)
# Out:
# === Generated Sample ===
# Every effort moves you,,,,,,,,,,,,,,.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ========================
# === Generated Sample ===
# Every effort moves you, and, and, and, and, and, and, and, and,, and,,,,, and, and,, and, and, and,,, and,,, and, and,,, and, and
# ========================
# === Generated Sample ===
# Every effort moves you, and to to to to to to to to to to to to to to to to to to to to to to to to to to to the to to the to to to to to to to to the to to to to to to to to
# ========================
# Ep 4 (Step 000035), Train loss 4.917, Val loss 6.329
# === Generated Sample ===
# Every effort moves you.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ========================
# === Generated Sample ===
# Every effort moves you know the, and in the picture--I was, and I had been the.
#
# "I, the fact, and.
# "I, and I had been the.
# "I, the fact, and the picture.
# "
# ========================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 8
#       3 optimizer = torch.optim.AdamW(
#       4 model.parameters(),
#       5 lr=0.0004, weight_decay=0.1
#       6 )
#       7 num_epochs = 10
# ----> 8 train_losses, val_losses, tokens_seen = train_model(
#       9 model, train_loader, val_loader, optimizer, device=torch.device("cpu"),
#      10 num_epochs=num_epochs, eval_freq=5, eval_iter=5,
#      11 start_context="Every effort moves you", tokenizer=tokenizer
#      12 )
#
# File E:\Git-projects\LLM_from_scratch\LLM_concepts\src\gpt_blocks\train_llm.py:48, in train_model(model, train_loader, val_loader, optimizer, device, num_epochs, eval_freq, eval_iter, start_context, tokenizer)
#      45 optimizer.zero_grad()
#      47 optimizer.zero_grad()
# ---> 48 loss = calc_loss_batch(input_batch, target_batch, model, device)
#      49 loss.backward()
#      50 optimizer.step()
#
# File E:\Git-projects\LLM_from_scratch\LLM_concepts\src\gpt_blocks\loss_calc.py:13, in calc_loss_batch(input_batch, target_batch, model, device)
#      11 input_batch = input_batch.to(device)
#      12 target_batch = target_batch.to(device)
# ---> 13 logits = model(input_batch)
#      14 loss = torch.nn.functional.cross_entropy(
#      15     logits.flatten(0, 1), target_batch.flatten()
#      16     )
#      17 return loss
#
# File e:\Git-projects\LLM_from_scratch\LLM_concepts\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File e:\Git-projects\LLM_from_scratch\LLM_concepts\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File E:\Git-projects\LLM_from_scratch\LLM_concepts\src\gpt_blocks\gpt_model.py:33, in GPTModel.forward(self, in_idx)
#      30 x = self.drop_embed(token_embeddings + position_embeddings)
#      32 # transformer blocks
# ---> 33 x = self.trf_blocks(x)
#      34 # final normalization and output head
#      35 x = self.final_norm(x)
#
# File e:\Git-projects\LLM_from_scratch\LLM_concepts\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File e:\Git-projects\LLM_from_scratch\LLM_concepts\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File e:\Git-projects\LLM_from_scratch\LLM_concepts\.venv\Lib\site-packages\torch\nn\modules\container.py:244, in Sequential.forward(self, input)
#     242 def forward(self, input):
#     243     for module in self:
# --> 244         input = module(input)
#     245     return input
#
# File e:\Git-projects\LLM_from_scratch\LLM_concepts\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File e:\Git-projects\LLM_from_scratch\LLM_concepts\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File E:\Git-projects\LLM_from_scratch\LLM_concepts\src\gpt_blocks\tranformer_block.py:32, in TransformerBlock.forward(self, x)
#      30 shortcut = x
#      31 x = self.norm2(x)
# ---> 32 x = self.ff(x)
#      33 x = self.drop(x)
#      34 x = x + shortcut
#
# File e:\Git-projects\LLM_from_scratch\LLM_concepts\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File e:\Git-projects\LLM_from_scratch\LLM_concepts\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File E:\Git-projects\LLM_from_scratch\LLM_concepts\src\gpt_blocks\nueral_network.py:16, in FeedForward.forward(self, x)
#      15 def forward(self, x):
# ---> 16     return self.layers(x)
#
# File e:\Git-projects\LLM_from_scratch\LLM_concepts\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File e:\Git-projects\LLM_from_scratch\LLM_concepts\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File e:\Git-projects\LLM_from_scratch\LLM_concepts\.venv\Lib\site-packages\torch\nn\modules\container.py:244, in Sequential.forward(self, input)
#     242 def forward(self, input):
#     243     for module in self:
# --> 244         input = module(input)
#     245     return input
#
# File e:\Git-projects\LLM_from_scratch\LLM_concepts\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File e:\Git-projects\LLM_from_scratch\LLM_concepts\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File e:\Git-projects\LLM_from_scratch\LLM_concepts\.venv\Lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
